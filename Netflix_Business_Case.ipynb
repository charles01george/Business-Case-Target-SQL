# %% [markdown]
# <a href="https://colab.research.google.com/github/charles01george/Business-Case-Target-SQL/blob/main/Netflix_Business_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the data
df = pd.read_csv("/content/drive/MyDrive/netflix.csv")

# %%
# Fining the Rows and Columns
df.shape
# Out:
# (8807, 12)

# %%
# To find the random data sample
df.sample(10)
# Out:
#      show_id     type                              title             director  \
# 645     s646    Movie                Murder by the Coast          Tània Balló
# 2198   s2199    Movie                          The Hater           Jan Komasa
# 4258   s4259    Movie                 The Birth Reborn 3      Eduardo Chauvet
# 5721   s5722    Movie  Kathleen Madigan: Bothering Jesus       Lorene Machado
# 4995   s4996    Movie                       Ladies First           Uraaz Bahl
# 4276   s4277  TV Show                               Wolf                  NaN
# 834     s835    Movie                       Blue Miracle       Julio Quintana
# 3833   s3834    Movie                        Shéhérazade  Jean-Bernard Marlin
# 6998   s6999  TV Show                       Horror Homes                  NaN
# 3501   s3502  TV Show                   Criminal: France                  NaN
#
#                                                    cast         country  \
# 645                                                 NaN             NaN
# 2198  Maciej Musiałowski, Agata Kulesza, Danuta Sten...          Poland
# 4258                                                NaN             NaN
# 5721                                   Kathleen Madigan   United States
# 4995                                                NaN           India
# 4276  Ahu Türkpençe, Serkan Çayoğlu, Murat Arkin, Em...          Turkey
# 834   Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...   United States
# 3833  Dylan Robert, Kenza Fortas, Idir Azougli, Lisa...          France
# 6998                                     Jill Halfpenny  United Kingdom
# 3501  Margot Bancilhon, Laurent Lucas, Stéphane Jobe...             NaN
#
#               date_added  release_year rating  duration  \
# 645        June 23, 2021          2021  TV-14    89 min
# 2198       July 29, 2020          2020  TV-MA   136 min
# 4258   December 28, 2018          2018  TV-14    73 min
# 5721   November 10, 2016          2016  TV-MA    71 min
# 4995       March 8, 2018          2018   TV-G    40 min
# 4276   December 21, 2018          2018  TV-MA  1 Season
# 834         May 27, 2021          2021  TV-PG    97 min
# 3833        May 11, 2019          2019  TV-MA   111 min
# 6998     October 2, 2019          2016  TV-14  1 Season
# 3501  September 20, 2019          2019  TV-MA  1 Season
#
#                                               listed_in  \
# 645                 Documentaries, International Movies
# 2198            Dramas, International Movies, Thrillers
# 4258                Documentaries, International Movies
# 5721                                    Stand-Up Comedy
# 4995  Documentaries, International Movies, Sports Mo...
# 4276  International TV Shows, TV Action & Adventure,...
# 834   Children & Family Movies, Dramas, Faith & Spir...
# 3833   Dramas, Independent Movies, International Movies
# 6998  British TV Shows, Docuseries, International TV...
# 3501  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             description
# 645   In 1999, teen Rocío Wanninkhof is murdered. He...
# 2198  A duplicitous young man finds success in the d...
# 4258  This intimate look at a São Paulo birth center...
# 5721  The Irish American comic riffs on everything f...
# 4995  Born amid poverty and limited women's rights i...
# 4276  Tasked with risky missions across Turkey, memb...
# 834   To save their cash-strapped orphanage, a guard...
# 3833  Fresh out of juvenile detention in Marseille, ...
# 6998  Dream homes turn into property nightmares when...
# 3501  Secrets emerge and entire cases unravel inside...

# %%
# Finding Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Finding Null
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Splitting the data and converting it to list and finally convert the whole to a Data Frame
df_director_r = pd.DataFrame(df["director"].apply(lambda x: str(x).split(", ")).tolist(), index = df["title"])
df_director = df_director_r.stack().reset_index()
df_director.drop("level_1", axis = 1, inplace = True)
df_director.rename(columns = {0 : "Directors"}, inplace = True)
df_director.sample(10)
# Out:
#                                    title           Directors
# 5493                      Mustang Island         Craig Elrod
# 2439             A Kid from Coney Island              Coodie
# 4415  Kevin James: Sweat the Small Stuff         Paul Miller
# 6703                       Attitude Test       Augusto Matte
# 2624                   Andaleeb El Dokki          Wael Ehsan
# 4817                                Jefe     Sergio Barrejón
# 670                Underworld: Awakening         Björn Stein
# 529               How to Become a Tyrant                 nan
# 2713                   Light in the Dark  Ekene Som Mekwunye
# 3415                        Okafor's Law         Omoni Oboli

# %%
df_cast_r = pd.DataFrame(df["cast"].apply(lambda x : str(x).split(", ")).tolist(), index = df["title"])
df_cast = df_cast_r.stack().reset_index()
df_cast.drop("level_1", axis = 1, inplace = True)
df_cast.rename(columns = {0 : "Cast"}, inplace = True)
df_cast.sample(10)
# Out:
#                             title                  Cast
# 59823               Summer of '92  Morten Vang Simonsen
# 41769                  One 2 Ka 4        Suresh Chatwal
# 7079     The Day I lost My Shadow        Sawsan Arsheed
# 61735           The King's Speech        Michael Gambon
# 53175           Kill Bill: Vol. 2       Claire Smithies
# 57092  Power Rangers Mystic Force        Holly Shanahan
# 52282          Inequality for All          Robert Reich
# 43414                     Rebirth          Harry Hamlin
# 14602              The Hows of Us        Daniel Padilla
# 27707               Locked on You        İştar Gökseven

# %%
df_country_r = pd.DataFrame(df["country"].apply(lambda x : str(x).split(", ")).tolist(), index = df["title"])
df_country = df_country_r.stack().reset_index()
df_country.drop("level_1", axis = 1, inplace = True)
df_country.rename(columns = {0 : "Country"}, inplace = True)
df_country.sample(10)
# Out:
#                          title        Country
# 4175   My Country: The New Age    South Korea
# 10240            The Iron Lady         France
# 2937             Before I Fall  United States
# 4995                  Innocent         Turkey
# 1790     Best of Stand-Up 2020            nan
# 4438               Point Blank         France
# 1736       Is Love Enough? Sir          India
# 4668             KO One Return            nan
# 7756                Chittagong  United States
# 747                The Tourist         France

# %%
df_listed_in_r = pd.DataFrame(df["listed_in"].apply(lambda x : str(x).split(", ")).tolist(), index = df["title"])
df_listed_in = df_listed_in_r.stack().reset_index()
df_listed_in.drop("level_1", axis = 1, inplace = True)
df_listed_in.rename(columns = {0 : "Listen_in"}, inplace = True)
df_listed_in.sample(10)
# Out:
#                                                title               Listen_in
# 15161                                       Gomorrah               TV Dramas
# 13158              The Battered Bastards of Baseball           Documentaries
# 15452                              Hotel Beau Séjour          Crime TV Shows
# 12985                                        Popples                Kids' TV
# 1031                                    Ridley Jones                Kids' TV
# 13707                         Avengers: Infinity War      Action & Adventure
# 19001  Undercover: How to Operate Behind Enemy Lines          Classic Movies
# 12700                           The Cuba Libre Story  International TV Shows
# 2115                      The Unremarkable Juanquini  International TV Shows
# 627             Monster Hunter: Legends of the Guild      Action & Adventure

# %%
df_new = df_director.merge(df_cast, how = "inner", on = "title")
df_new.head()
# Out:
#                   title        Directors            Cast
# 0  Dick Johnson Is Dead  Kirsten Johnson             nan
# 1         Blood & Water              nan      Ama Qamata
# 2         Blood & Water              nan     Khosi Ngema
# 3         Blood & Water              nan   Gail Mabalane
# 4         Blood & Water              nan  Thabang Molaba

# %%
df_new = df_new.merge(df_country, how = "inner", on = "title")
df_new
# Out:
#                       title        Directors                   Cast  \
# 0      Dick Johnson Is Dead  Kirsten Johnson                    nan
# 1             Blood & Water              nan             Ama Qamata
# 2             Blood & Water              nan            Khosi Ngema
# 3             Blood & Water              nan          Gail Mabalane
# 4             Blood & Water              nan         Thabang Molaba
# ...                     ...              ...                    ...
# 89377                Zubaan      Mozez Singh       Manish Chaudhary
# 89378                Zubaan      Mozez Singh           Meghna Malik
# 89379                Zubaan      Mozez Singh          Malkeet Rauni
# 89380                Zubaan      Mozez Singh         Anita Shabdish
# 89381                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#              Country
# 0      United States
# 1       South Africa
# 2       South Africa
# 3       South Africa
# 4       South Africa
# ...              ...
# 89377          India
# 89378          India
# 89379          India
# 89380          India
# 89381          India
#
# [89382 rows x 4 columns]

# %%
df_new = df_new.merge(df_listed_in, on = "title", how = "inner")

# %%
df_new
# Out:
#                        title        Directors                   Cast  \
# 0       Dick Johnson Is Dead  Kirsten Johnson                    nan
# 1              Blood & Water              nan             Ama Qamata
# 2              Blood & Water              nan             Ama Qamata
# 3              Blood & Water              nan             Ama Qamata
# 4              Blood & Water              nan            Khosi Ngema
# ...                      ...              ...                    ...
# 201986                Zubaan      Mozez Singh         Anita Shabdish
# 201987                Zubaan      Mozez Singh         Anita Shabdish
# 201988                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201989                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201990                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#               Country               Listen_in
# 0       United States           Documentaries
# 1        South Africa  International TV Shows
# 2        South Africa               TV Dramas
# 3        South Africa            TV Mysteries
# 4        South Africa  International TV Shows
# ...               ...                     ...
# 201986          India    International Movies
# 201987          India        Music & Musicals
# 201988          India                  Dramas
# 201989          India    International Movies
# 201990          India        Music & Musicals
#
# [201991 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_final = df_new.merge(df[['show_id', 'type', 'title', 'date_added',
       'release_year', 'rating', 'duration']], on = "title", how = 'left')
df_final.head()
# Out:
#                   title        Directors         Cast        Country  \
# 0  Dick Johnson Is Dead  Kirsten Johnson          nan  United States
# 1         Blood & Water              nan   Ama Qamata   South Africa
# 2         Blood & Water              nan   Ama Qamata   South Africa
# 3         Blood & Water              nan   Ama Qamata   South Africa
# 4         Blood & Water              nan  Khosi Ngema   South Africa
#
#                 Listen_in show_id     type          date_added  release_year  \
# 0           Documentaries      s1    Movie  September 25, 2021          2020
# 1  International TV Shows      s2  TV Show  September 24, 2021          2021
# 2               TV Dramas      s2  TV Show  September 24, 2021          2021
# 3            TV Mysteries      s2  TV Show  September 24, 2021          2021
# 4  International TV Shows      s2  TV Show  September 24, 2021          2021
#
#   rating   duration
# 0  PG-13     90 min
# 1  TV-MA  2 Seasons
# 2  TV-MA  2 Seasons
# 3  TV-MA  2 Seasons
# 4  TV-MA  2 Seasons

# %%
df_final.isnull().sum()
# Out:
# title             0
# Directors         0
# Cast              0
# Country           0
# Listen_in         0
# show_id           0
# type              0
# date_added      158
# release_year      0
# rating           67
# duration          3
# dtype: int64

# %%
# Change the nan value to Unknown Actor
df_final["Cast"].replace(["nan"], ["Unknown Actor"], inplace = True)

# Replace nan value in director to Unknown Director
df_final["Directors"].replace({"nan" : "Unknown Director"}, inplace = True)

df_final.head()
# Out:
#                   title         Directors           Cast        Country  \
# 0  Dick Johnson Is Dead   Kirsten Johnson  Unknown Actor  United States
# 1         Blood & Water  Unknown Director     Ama Qamata   South Africa
# 2         Blood & Water  Unknown Director     Ama Qamata   South Africa
# 3         Blood & Water  Unknown Director     Ama Qamata   South Africa
# 4         Blood & Water  Unknown Director    Khosi Ngema   South Africa
#
#                 Listen_in show_id     type          date_added  release_year  \
# 0           Documentaries      s1    Movie  September 25, 2021          2020
# 1  International TV Shows      s2  TV Show  September 24, 2021          2021
# 2               TV Dramas      s2  TV Show  September 24, 2021          2021
# 3            TV Mysteries      s2  TV Show  September 24, 2021          2021
# 4  International TV Shows      s2  TV Show  September 24, 2021          2021
#
#   rating   duration
# 0  PG-13     90 min
# 1  TV-MA  2 Seasons
# 2  TV-MA  2 Seasons
# 3  TV-MA  2 Seasons
# 4  TV-MA  2 Seasons

# %%
# Duration missing values
df_final[df_final["duration"].isnull()]
# Out:
#                                        title   Directors        Cast  \
# 126537                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# 131603                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# 131737  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#               Country Listen_in show_id   type          date_added  \
# 126537  United States    Movies   s5542  Movie       April 4, 2017
# 131603  United States    Movies   s5795  Movie  September 16, 2016
# 131737  United States    Movies   s5814  Movie     August 15, 2016
#
#         release_year  rating duration
# 126537          2017  74 min      NaN
# 131603          2010  84 min      NaN
# 131737          2015  66 min      NaN

# %%
df_final[df_final["date_added"].isnull()]
# Out:
#                                               title         Directors  \
# 136893  A Young Doctor's Notebook and Other Stories  Unknown Director
# 136894  A Young Doctor's Notebook and Other Stories  Unknown Director
# 136895  A Young Doctor's Notebook and Other Stories  Unknown Director
# 136896  A Young Doctor's Notebook and Other Stories  Unknown Director
# 136897  A Young Doctor's Notebook and Other Stories  Unknown Director
# ...                                             ...               ...
# 186891                 The Adventures of Figaro Pho  Unknown Director
# 186892                 The Adventures of Figaro Pho  Unknown Director
# 186893                 The Adventures of Figaro Pho  Unknown Director
# 186894                 The Adventures of Figaro Pho  Unknown Director
# 186895                 The Adventures of Figaro Pho  Unknown Director
#
#                          Cast         Country         Listen_in show_id  \
# 136893       Daniel Radcliffe  United Kingdom  British TV Shows   s6067
# 136894       Daniel Radcliffe  United Kingdom       TV Comedies   s6067
# 136895       Daniel Radcliffe  United Kingdom         TV Dramas   s6067
# 136896               Jon Hamm  United Kingdom  British TV Shows   s6067
# 136897               Jon Hamm  United Kingdom       TV Comedies   s6067
# ...                       ...             ...               ...     ...
# 186891       Charlotte Hamlyn       Australia       TV Comedies   s8183
# 186892  Stavroula Mountzouris       Australia          Kids' TV   s8183
# 186893  Stavroula Mountzouris       Australia       TV Comedies   s8183
# 186894        Aletheia Burney       Australia          Kids' TV   s8183
# 186895        Aletheia Burney       Australia       TV Comedies   s8183
#
#            type date_added  release_year rating   duration
# 136893  TV Show        NaN          2013  TV-MA  2 Seasons
# 136894  TV Show        NaN          2013  TV-MA  2 Seasons
# 136895  TV Show        NaN          2013  TV-MA  2 Seasons
# 136896  TV Show        NaN          2013  TV-MA  2 Seasons
# 136897  TV Show        NaN          2013  TV-MA  2 Seasons
# ...         ...        ...           ...    ...        ...
# 186891  TV Show        NaN          2015  TV-Y7  2 Seasons
# 186892  TV Show        NaN          2015  TV-Y7  2 Seasons
# 186893  TV Show        NaN          2015  TV-Y7  2 Seasons
# 186894  TV Show        NaN          2015  TV-Y7  2 Seasons
# 186895  TV Show        NaN          2015  TV-Y7  2 Seasons
#
# [158 rows x 11 columns]

# %%
df_final["date_added"].mode()
# Out:
# 0    January 1, 2020
# Name: date_added, dtype: object

# %%
df_final[df_final["date_added"].isnull()]["release_year"].value_counts()
# Out:
# release_year
# 2015    40
# 2008    36
# 2013    27
# 2003    24
# 2012    24
# 2016     5
# 2018     1
# 2010     1
# Name: count, dtype: int64
